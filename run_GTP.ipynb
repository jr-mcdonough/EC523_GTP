# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# train the feature extractor

# %run -i /content/drive/My\ Drive/EC523/EC523_GTP/FeatureExtractor/train_feature_extractor.py \
--root_dir '/content/drive/My Drive/EC523/EC523_GTP' \
--yaml_file 'config.yaml'
# Out:
# Epoch (1/30), step 25: training loss 6.235191
# Epoch (1/30), step 50: training loss 6.231633
# Epoch (1/30), step 75: training loss 6.193564
# Epoch (1/30), step 100: training loss 6.117842
# Epoch (1/30), step 125: training loss 5.718567
#
# Epoch (1/30): training loss 6.126034
# Epoch (1/30): validation loss 5.589463
#
# Epoch (2/30), step 25: training loss 5.313273
# Epoch (2/30), step 50: training loss 5.076962
# Epoch (2/30), step 75: training loss 4.994688
# Epoch (2/30), step 100: training loss 4.917516
# Epoch (2/30), step 125: training loss 4.885058
#
# Epoch (2/30): training loss 5.097015
# Epoch (2/30): validation loss 4.874756
#
# Epoch (3/30), step 25: training loss 4.824458
# Epoch (3/30), step 50: training loss 4.832639
# Epoch (3/30), step 75: training loss 4.782234
# Epoch (3/30), step 100: training loss 4.802741
# Epoch (3/30), step 125: training loss 4.764852
#
# Epoch (3/30): training loss 4.812289
# Epoch (3/30): validation loss 4.752114
#
# ...

# %%
# build graphs

# %run -i /content/drive/My\ Drive/EC523/EC523_GTP/BuildGraphs/build_graphs.py \
--root_dir '/content/drive/My Drive/EC523/EC523_GTP' \
--yaml_file 'config.yaml'
# Out:
# /content/drive/My Drive/EC523/EC523_GTP/BuildGraphs/build_graphs.py:73: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# make sure pytorch_geometric is installed

import os
import torch

os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# Out:
# 2.5.1+cu121
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 43.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 12.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# train the graph transformer

# %run -i /content/drive/My\ Drive/EC523/EC523_GTP/GraphTransformer/train_graph_transformer.py \
--root_dir '/content/drive/My Drive/EC523/EC523_GTP' \
--yaml_file 'config.yaml'
# Out:
# /content/drive/My Drive/EC523/EC523_GTP/GraphTransformer/dataset.py:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   graph_data = torch.load(data_path,
# ...

# %%
# disconnect colab runtime after execution finishes

from google.colab import runtime
runtime.unassign()
